# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# Ans👉 when we creating Exception class its inherit from Exception class which is super class thats provide us basic functionality
# which is helpful for handled the exception .

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
# Python program to print the Exception Hierarchy

def print_exception_hierarchy(exception, indent=0):
    for Hierarchy in exception:
        print(' ' * indent + Hierarchy.__name__)
        print_exception_hierarchy(Hierarchy.__subclasses__(), indent + 2)
        
print_exception_hierarchy([Exception])
# Out:
# Exception
#   TypeError
#     FloatOperation
#     MultipartConversionError
#   StopAsyncIteration
#   StopIteration
#   ImportError
#     ModuleNotFoundError
#     ZipImportError
#   OSError
#     ConnectionError
#       BrokenPipeError
#       ConnectionAbortedError
#       ConnectionRefusedError
#       ConnectionResetError
#         RemoteDisconnected
#     BlockingIOError
#     ChildProcessError
#     FileExistsError
#     FileNotFoundError
#     IsADirectoryError
#     NotADirectoryError
#     InterruptedError
#       InterruptedSystemCall
#     PermissionError
#     ProcessLookupError
#     TimeoutError
#     UnsupportedOperation
#     itimer_error
#     herror
#     gaierror
#     SSLError
#       SSLCertVerificationError
#       SSLZeroReturnError
#       SSLWantWriteError
#       SSLWantReadError
#       SSLSyscallError
#       SSLEOFError
#     Error
#       SameFileError
#     SpecialFileError
#     ExecError
#     ReadError
#     URLError
#       HTTPError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
# ArithmeticError class is a subclass of Exception class which is ocurred during arthmetic operation which has many error
# 1. ZeroDivisionError
try:
    a= 3
    a/0
except ZeroDivisionError as e:
    print(e.__class__.__name__,":",e)
# 2. valueError
try:
    a = int("ravi")
except ValueError as e :
    print(e.__class__.__name__,":",e)
# Out:
# ZeroDivisionError : division by zero
# ValueError : invalid literal for int() with base 10: 'ravi'

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
# Ans👉 LookupError is base class of all looluperror it is used when we want to access through list or dict this class handled the error
# example
# KeyError :- When we try to access a key in the dict and that's not found in the dict then its throw KeyError

data = {"r": 1, "a" : 2, "v" : 3}

try:
    print(data["i"])
    print(data2[3])
except Exception as e:
    print(e.__class__.__name__)
    
# IndexError :- When we try to access index from a list that doesn't exists in the list then its throw IndexError 

data2 = [1,3,4]
try:
    print(data2[3])
except Exception as e:
    print(e.__class__.__name__)
# Out:
# KeyError
# IndexError

# %% [markdown]
# Ans👉 ImporError is a subclass of Exception class which is handled the error when import module file name not in the library and ModuleNotFoundError is a subclass of ImportError same as
# ImportError but its raised specific error with the name of module which is not found.

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %%
# Ans👉 
import logging
logging.basicConfig(filename = "error.log", level = logging.ERROR)
try:
    with open("practice.text", "r") as p:
        p.read()
except FileNotFoundError as e:
    logging.error("i am handling {} {} ".format(e.__class__.__name__, e))
finally:
    p.close()
try:
    1/0
except ZeroDivisionError as e:
    logging.error("i am handling {} {} ".format(e.__class__.__name__, e))
