# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask Framework is a micro Framework for python which is designed as simple and lightweight which is provides features to build web application and Api.
# These are following advantages of flask Framework:-
# 1. it is lightweight and easy to handle
# 2. it is flexible it doesn't force to build a specific architecture or design pattern which makes it easy to use as specific needs
# 3. it has many plugins which is helps to add functionality to your applictation
# 4. it provides built in support for testing . you can test your application an resolved your bug before production.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:86bccecf-bc35-4323-9105-d7c22d799c37.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is a process which is helps to make url of a funcion of my Flask application. its allow us to make different pattern for different function that
# handle request and response for our function.
# using  app routes, we can create different views for different parts of our application and handle user interactions accordingly.
# we use app routes because its helps us to make daynamic web application to handle multiple request and response with apporiate response

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:655f15ae-f291-4b3c-97cb-044c7d9b56a2.png) , ![image.png](attachment:dc0d01e0-9da0-448e-b128-7b4747dabdb2.png),![image.png](attachment:76cf54d6-569a-47a2-9c49-f0076fbd2c3e.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %%
# url_for() function is used in Flask for URL Building.
from flask import Flask , url_for

app = Flask(__name__)

@app.route("/")
def home():
    return "this is my home page"

@app.route('/about')
def about():
    return "this is my about us page"

@app.route("/contact")
def contact():
    return "this is my contact us page"

with app.test_request_context():
    print(url_for('home'))
    print(url_for('contact'))
    print(url_for('about'))


if __name__ == "__main__":
    app.run(host="0.0.0.0")
